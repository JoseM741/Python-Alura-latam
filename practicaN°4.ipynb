# %% [markdown]
#  Crea un programa que tenga la siguiente lista con los gastos de una empresa de papel [2172.54, 3701.35, 3518.09, 3456.61, 3249.38, 2840.82, 3891.45, 3075.26, 2317.64, 3219.08]. Con estos valores, crea un programa que calcule el promedio de gastos. Sugerencia: usa las funciones integradas sum() y len().

# %%
gastos_empresa = [2172.54, 3701.35, 3518.09, 3456.61, 3249.38, 2840.82, 3891.45, 3075.26, 2317.64, 3219.08]
suma_gastos = sum(gastos_empresa)
cant_registros = len(gastos_empresa)
promedio_gastos = suma_gastos / cant_registros
print(f'El promedio_gastos es: ',promedio_gastos )
# Out:
# El promedio_gastos es:  3144.222

# %% [markdown]
# Con los mismos datos de la pregunta anterior, determina cuántas compras se realizaron por encima de 3000 reales y calcula el porcentaje con respecto al total de compras.

# %%
compras_mayores_a_3000 = [gastos_empresa for gastos_empresa in gastos_empresa if gastos_empresa > 3000]
numero_compras_mayores_a_3000 = len(compras_mayores_a_3000)

# Calcular el porcentaje de compras mayores a 3000 reales
porcentaje_compras_mayores_a_3000 = (numero_compras_mayores_a_3000 / len(gastos)) * 100

# Resultados
print("Número de compras mayores a 3000 reales:", numero_compras_mayores_a_3000)
print("Porcentaje con respecto al total de compras: {:.2f}%".format(porcentaje_compras_mayores_a_3000))
# Out:
# Número de compras mayores a 3000 reales: 7
# Porcentaje con respecto al total de compras: 70.00%

# %%
# Lista de gastos de la empresa de papel
gastos = [2172.54, 3701.35, 3518.09, 3456.61, 3249.38, 2840.82, 3891.45, 3075.26, 2317.64, 3219.08]

# Inicializar contador para las compras mayores a 3000
contador = 0

# Recorrer cada gasto en la lista
for gasto in gastos:
    if gasto > 3000:
        contador += 1  # Incrementar el contador si el gasto supera los 3000

# Calcular el porcentaje respecto al total de compras
porcentaje = (contador / len(gastos)) * 100

# Mostrar resultados
print("Número de compras mayores a 3000 reales:", contador)
print("Porcentaje con respecto al total de compras: {:.2f}%".format(porcentaje))
# Out:
# Número de compras mayores a 3000 reales: 7
# Porcentaje con respecto al total de compras: 70.00%

# %% [markdown]
# Crea un código que recoja en una lista 5 números enteros aleatorios e imprima la lista. Ejemplo: [1, 4, 7, 2, 4].

# %%
# Lista que almacenará los 5 números enteros
lista_numeros = []

# Creamos un bucle que iterará 5 veces para recibir los 5 números
for i in range(0, 5):

# Recopilamos el valor e lo insertamos en la lista 5 veces
  numero = int(input('Ingresa un número entero: '))
  lista_numeros.append(numero)

# Resultado
print(f'Lista de números ingresados: {lista_numeros}')
# Out:
# Ingresa un número entero: 9
# Ingresa un número entero: 7
# Ingresa un número entero: 5
# Ingresa un número entero: 3
# Ingresa un número entero: 1
# Lista de números ingresados: [9, 7, 5, 3, 1]

# %% [markdown]
# Recoge nuevamente 5 números enteros e imprime la lista en orden inverso al enviado.

# %%
lista_numeros2 = []
for i in range(0,5):
  numeros = int(input('Ingresa un número entero: '))
  lista_numeros2.append(numeros)
print(f'Lista de números ingresados: {lista_numeros2}')
lista_numeros2.reverse()
print(f'Lista de números ingresados en orden inverso: {lista_numeros2}')
# Out:
# Ingresa un número entero: 1
# Ingresa un número entero: 3
# Ingresa un número entero: 5
# Ingresa un número entero: 7
# Ingresa un número entero: 9
# Lista de números ingresados: [1, 3, 5, 7, 9]
# Lista de números ingresados en orden inverso: [9, 7, 5, 3, 1]

# %% [markdown]
#  Escribe un programa que pida una fecha, especificando el día, mes y año, y determine si es válida para su análisis.

# %%
# Recopilamos la fecha
dia = int(input('Ingrese el día: '))
mes = int(input('Ingrese el mes: '))
año = int(input('Ingrese el año: '))

# Análisis de febrero
if mes == 2:
  # Verificamos si es o no un año bisiesto
  if año % 4 == 0 and (año % 400 == 0 or año % 100 != 0):
    dias_febrero = 29
  else:
    dias_febrero = 28
  # Verificamos si el día ingresado coincide con el máximo de días de febrero
  if dia >= 1 and dia <= dias_febrero:
    print('Fecha válida')
  else:
    print('Fecha inválida')
# Verificamos meses que terminan en 31 días
elif mes in [1, 3, 5, 7, 8, 10, 12]:
  if dia >= 1 and dia <= 31:
    print('Fecha válida')
  else:
    print('Fecha inválida')
# Verificamos meses que terminan en 30 días
elif mes in [4, 6, 9, 11]:
  if dia >= 1 and dia <= 30:
    print('Fecha válida')
  else:
    print('Fecha inválida')
# Si el mes no está entre 1 y 12
else:
  print('Fecha inválida')
# Out:
# Ingrese el día: 26
# Ingrese el mes: 12
# Ingrese el año: 1973
# Fecha válida

# %% [markdown]
#  Para un estudio sobre la multiplicación de bacterias en una colonia, se recopiló el número de bacterias multiplicadas por día y se puede observar a continuación: [1.2, 2.1, 3.3, 5.0, 7.8, 11.3, 16.6, 25.1, 37.8, 56.9]. Con estos valores, crea un código que genere una lista que contenga el porcentaje de crecimiento de bacterias por día, comparando el número de bacterias en cada día con el número de bacterias del día anterior. Sugerencia: para calcular el porcentaje de crecimiento, utiliza la siguiente ecuación: 100 * (muestra_actual - muestra_anterior) / muestra_anterior.

# %%
bacterias_pordia = [1.2, 2.1, 3.3, 5.0, 7.8, 11.3, 16.6, 25.1, 37.8, 56.9]

###lista que almacena la tasa de crecimiento###
porcentaje_crecimiento = []

# Recorremos los índices de 1 a 9 para comparar los valores actuales con los anteriores
for i in range(1, len(bacterias_pordia)):

# Realizamos el cálculo: 100 * (muestra_actual - muestra_anterior) / (muestra_anterior)
  porcentaje = 100 * (bacterias_pordia[i] - bacterias_pordia[i-1]) / (bacterias_pordia[i-1])

# Agregamos el resultado a la lista
  porcentaje_crecimiento.append(porcentaje)

# Resultado
print(f'Porcentajes de crecimiento:\n{porcentaje_crecimiento}')
# Out:
# Porcentajes de crecimiento:
# [75.00000000000001, 57.142857142857125, 51.51515151515153, 56.0, 44.87179487179489, 46.90265486725664, 51.20481927710843, 50.59760956175297, 50.52910052910054]

# %% [markdown]
#  Para una selección de productos alimenticios, debemos separar el conjunto de IDs proporcionados por números enteros, sabiendo que los productos con ID par son dulces y los que tienen ID impar son amargos. Crea un código que recoja 10 IDs. Luego, calcula y muestra la cantidad de productos dulces y amargos.

# %%
# Lista que contendrá los valores de IDs
ids = []
# Variables contadoras de dulces y amargos
dulce = 0
amargo = 0

# Creamos un bucle que iterará 10 veces para recopilar los 10 IDs
for i in range(0,10):
  # Recopilamos el ID y lo agregamos a la lista
  ids.append(int(input(f'Ingrese el ID {i+1}°: ')))

# Leemos todos los elementos de la lista de IDs y los asignamos a id
for id in ids:
  # Verificamos si los elementos son pares o impares para llevar el conteo
  if id % 2 == 0:
    dulce += 1
  else:
    amargo += 1

# Resultado
print(f'Cantidad de productos dulces: {dulce}')
print(f'Cantidad de productos amargos: {amargo}')
# Out:
# Ingrese el ID 1°: 1
# Ingrese el ID 2°: 2
# Ingrese el ID 3°: 3
# Ingrese el ID 4°: 4
# Ingrese el ID 5°: 5
# Ingrese el ID 6°: 6
# Ingrese el ID 7°: 7
# Ingrese el ID 8°: 8
# Ingrese el ID 9°: 9
# Ingrese el ID 10°: 10
# Cantidad de productos dulces: 5
# Cantidad de productos amargos: 5

# %% [markdown]
# Desarrolla un programa que informe la puntuación de un estudiante de acuerdo con sus respuestas. Debe pedir la respuesta del estudiante para cada pregunta y verificar si la respuesta coincide con el resultado. Cada pregunta vale un punto y hay opciones A, B, C o D.
#
# Resultado del examen:
# 01 - D
# 02 - A
# 03 - C
# 04 - B
# 05 - A
# 06 - D
# 07 - C
# 08 - C
# 09 - A
# 10 - B

# %%
# Inicializamos los datos
respuestas = []  # Lista para almacenar las respuestas
# Lista de respuestas correctas
gabarito = ['D', 'A', 'C', 'B', 'A', 'D', 'C', 'C', 'A', 'B']
nota = 0  # Acumulará la nota total

# Recopilamos las respuestas del estudiante
for i in range(0, 10):
  respuestas.append(input(f'Introduzca la respuesta a la pregunta {i + 1}: ').upper())

# Verificamos si las respuestas coinciden y las sumamos a la nota
for i in range(0, 10):
  if respuestas[i] == gabarito[i]:
    nota += 1

# Mostrando la nota final
print(f'Nota final: {nota}')
# Out:
# Introduzca la respuesta a la pregunta 1: G
# Introduzca la respuesta a la pregunta 2: A
# Introduzca la respuesta a la pregunta 3: B
# Introduzca la respuesta a la pregunta 4: C
# Introduzca la respuesta a la pregunta 5: A
# Introduzca la respuesta a la pregunta 6: B
# Introduzca la respuesta a la pregunta 7: C
# Introduzca la respuesta a la pregunta 8: D
# Introduzca la respuesta a la pregunta 9: A
# Introduzca la respuesta a la pregunta 10: A
# Nota final: 4

# %% [markdown]
# Un instituto de meteorología desea realizar un estudio de la temperatura media de cada mes del año. Para ello, debes crear un código que recoja y almacene esas temperaturas medias en una lista. Luego, calcula el promedio anual de las temperaturas y muestra todas las temperaturas por encima del promedio anual y en qué mes ocurrieron, mostrando los meses por su nombre (Enero, Febrero, etc.).

# %%
## Nombre de los Meses ##
meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre' ]

## Lista para almacenar las temperaturas medias de cada mes ##
temperaturas = []

## Recolección de datos de temperatura ##
print("Introduce la temperatura media de cada mes:")
for mes in meses:
    temp = float(input(f"{mes}: "))
    temperaturas.append(temp)

# Nombres de los meses
meses = ["Enero", "Febrero", "Marzo", "Abril", "Mayo", "Junio",
         "Julio", "Agosto", "Septiembre", "Octubre", "Noviembre", "Diciembre"]

# Lista para almacenar las temperaturas medias de cada mes
temperaturas = []

# Recolección de datos de temperatura
print("Introduce la temperatura media de cada mes:")
for mes in meses:
    temp = float(input(f"{mes}: "))
    temperaturas.append(temp)

# Cálculo del promedio anual
promedio_anual = sum(temperaturas) / len(temperaturas)

# Mostrar el promedio anual
print(f"\nEl promedio anual de las temperaturas es: {promedio_anual:.2f}°C")

# Buscar y mostrar las temperaturas por encima del promedio anual
print("\nTemperaturas por encima del promedio anual:")
for i, temp in enumerate(temperaturas):
    if temp > promedio_anual:
        print(f"{meses[i]}: {temp}°C")
# Out:
# Introduce la temperatura media de cada mes:
# Enero: 5
# Febrero: 5
# Marzo: 5
# Abril: 5
# Mayo: 5
# Junio: 5
# Julio: 5
# Agosto: 5
# Septiembre: 5
# Octubre: 5
# Noviembre: 5
# Diciembre: 5
# Introduce la temperatura media de cada mes:
# Enero: 7
# Febrero: 7
# Marzo: 7
# Abril: 7
# Mayo: 7
# Junio: 7
# Julio: 7
# Agosto: 7
# Septiembre: 7
# Octubre: 7
# Noviembre: 7
# Diciembre: 7
#
# El promedio anual de las temperaturas es: 7.00°C
#
# Temperaturas por encima del promedio anual:

# %% [markdown]
# Una empresa de comercio electrónico está interesada en analizar las ventas de sus productos. Los datos de ventas se han almacenado en un diccionario:
# Escribe un código que calcule el total de ventas y el producto más vendido.

# %%
datos_ventas = {'Producto A': 300, 'Producto B': 80, 'Producto C': 60, 'Producto D': 200, 'Producto E': 250, 'Producto F': 30}

total_ventas = sum(datos_ventas.values())
producto_mas_vendido = max(datos_ventas, key=datos_ventas.get)

print(f'Total de ventas: {total_ventas}')
print(f'Producto más vendido: {producto_mas_vendido}')
# Out:
# Total de ventas: 920
# Producto más vendido: Producto A

# %% [markdown]
# Los empleados de un departamento de tu empresa recibirán una bonificación del 10% de su salario debido a un excelente rendimiento del equipo. El departamento de finanzas ha solicitado tu ayuda para verificar las consecuencias financieras de esta bonificación en los recursos. Se te ha enviado una lista con los salarios que recibirán la bonificación: [1172, 1644, 2617, 5130, 5532, 6341, 6650, 7238, 7685, 7782, 7903]. La bonificación de cada empleado no puede ser inferior a 200. En el código, convierte cada uno de los salarios en claves de un diccionario y la bonificación de cada salario en el valor correspondiente. Luego, informa el gasto total en bonificaciones, cuántos empleados recibieron la bonificación mínima y cuál fue el valor más alto de la bonificación proporcionada.

# %%
# Lista de salarios
salarios = [1172, 1644, 2617, 5130, 5532, 6341, 6650, 7238, 7685, 7782, 7903]

# Diccionario para las bonificaciones
bonificaciones = {}
for salario in salarios:
    bonificaciones[salario] = max(salario * 0.10, 200)

# Resultados
gasto_total = sum(bonificaciones.values())
empleados_bon_minima = list(bonificaciones.values()).count(200)
bonificacion_maxima = max(bonificaciones.values())

print(f"Gasto total en bonificaciones: {gasto_total}")
print(f"Empleados con bonificación mínima: {empleados_bon_minima}")
print(f"Bonificación más alta: {bonificacion_maxima}")
# Out:
# Gasto total en bonificaciones: 6087.8
# Empleados con bonificación mínima: 2
# Bonificación más alta: 790.3000000000001
